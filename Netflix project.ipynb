# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("netflix_2500.csv")

# %%
df.head()
# Out:
#   show_id     type    title      director             cast         country  \
# 0      s1    Movie  Title_1    John Smith  Actor E|Actor D          Canada
# 1      s2    Movie  Title_2  David Miller  Actor D|Actor I           Japan
# 2      s3  TV Show  Title_3    Farah Khan  Actor E|Actor A  United Kingdom
# 3      s4    Movie  Title_4     Rahul Sen  Actor G|Actor B     South Korea
# 4      s5  TV Show  Title_5     Rahul Sen  Actor I|Actor E           Japan
#
#    date_added  release_year rating   duration         listed_in
# 0  2018-07-26          2016     PG    134 min    Action|Fantasy
# 1  2017-04-19          2023      R    149 min   Horror|Thriller
# 2  2021-09-28          2020   TV-G  2 Seasons   Thriller|Sci-Fi
# 3  2020-11-09          2019      G    138 min   Adventure|Drama
# 4  2021-01-21          2018     PG  1 Seasons  Fantasy|Thriller

# %%
df['date_added'] = pd.to_datetime(df['date_added'])

# %%
df['year_added'] = df["date_added"].dt.year
df["month_added"] = df["date_added"].dt.month

# %%
type_counts = df['type'].value_counts()
print(type_counts)
# Out:
# type
# Movie      1273
# TV Show    1227
# Name: count, dtype: int64

# %%
year_trend = df.groupby("year_added").size()
print(year_trend)
# Out:
# year_added
# 2017    387
# 2018    384
# 2019    315
# 2020    362
# 2021    353
# 2022    339
# 2023    360
# dtype: int64

# %%
top_countries = df["country"].value_counts().head(10)
print(top_countries)
# Out:
# country
# Brazil            272
# United States     268
# Canada            262
# Australia         259
# India             256
# France            243
# Germany           242
# Japan             236
# South Korea       233
# United Kingdom    229
# Name: count, dtype: int64

# %%
df['genre'] = df['listed_in'].str.split('|').str[0]

# %%
top_genres = df["genre"].value_counts()
print(top_genres)
# Out:
# genre
# Horror         242
# Thriller       241
# Drama          235
# Documentary    232
# Adventure      231
# Action         229
# Sci-Fi         227
# Fantasy        225
# Crime          222
# Comedy         209
# Romance        207
# Name: count, dtype: int64

# %%
ratings = df["rating"].value_counts()
print(ratings)
# Out:
# rating
# PG-13    350
# PG       341
# TV-14    331
# R        316
# TV-MA    299
# G        296
# TV-G     286
# TV-PG    281
# Name: count, dtype: int64

# %%
type_counts.plot(kind="bar")
plt.title("Movies vs TV Shows")
plt.xlabel("Type")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
year_trend.plot(kind="line")
plt.title("Content Over The Year")
plt.xlabel("Year")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
top_countries.plot(kind="bar")
plt.title("Top 10 Countries")
plt.xlabel("Countries")
# Out:
# Text(0.5, 0, 'Countries')

# %%
top_genres.plot(kind="bar")
plt.title("Top Genres")
# Out:
# Text(0.5, 1.0, 'Top Genres')
